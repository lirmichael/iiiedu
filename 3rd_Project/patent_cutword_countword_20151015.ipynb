# %%
import requests

import os
#os.mkdir('patent_cutword')

import sys
sys.path.append('../')

import jieba
import jieba.analyse
from optparse import OptionParser
import operator

from bs4 import BeautifulSoup as bs

jieba.set_dictionary('dict.txt.big')
jieba.load_userdict("E:\Project\patent\iiiedu\dictionary\MECH_conver_cut_space_1.txt")

jieba.analyse.set_stop_words("E:\Project\patent\iiiedu\dictionary\stop_words.txt")
jieba.analyse.set_idf_path("E:\Project\patent\iiiedu\dictionary\idf.txt.big");

import jieba.analyse
from optparse import OptionParser

from bs4 import BeautifulSoup as bs
f = open('E:\\Project\\patent\\iiiedu\\Full_article\\F01C_001\\271209.xml', 'rb')
response_text = f.read()
f.close()

#print "Input :\n"
#print content

#print type(content)
res = bs(response_text)
print res.text



seg_list1 = jieba.cut(res.text, cut_all=True)
print "\n"
#print("1. Full Mode: " + "/ ".join(seg_list1))  # 全模式

a = ", ".join(seg_list1)
dic = {}
#print a.split(',')
for w in  [c.strip() for c in a.split(',')]:
    #for w in jieba.cut(ent.select('.title')[0].text.strip()):
    if dic.get(w) is None:
        dic[w] = 1
    else:
        dic[w] = dic[w] + 1
sorted_x = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)

print("1. Full Mode: " )  # 全模式
print "sorted result: "
for w in sorted_x:
    #print w[0], w[1], 
    print w[0], w[1],

seg_list2 = jieba.cut(res.text, cut_all=False)
#print("2. Default Mode: " + "/ ".join(seg_list2))  # 精确模式
print "\n"
print("2. 精确模式:")
#print(", ".join(seg_list3))
a = ", ".join(seg_list2)
dic = {}
#print a.split(',')
for w in  [c.strip() for c in a.split(',')]:
    #for w in jieba.cut(ent.select('.title')[0].text.strip()):
    if dic.get(w) is None:
        dic[w] = 1
    else:
        dic[w] = dic[w] + 1

sorted_x = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)
print "sorted result: "
for w in sorted_x:
    #print w[0], w[1], 
    print w[0], w[1], 

seg_list3 = jieba.cut(res.text)  # 默认是精确模式
print "\n"
print("3. 默认精确模式:")
#print(", ".join(seg_list3))
a = ", ".join(seg_list3)
dic = {}
#print a.split(',')
for w in  [c.strip() for c in a.split(',')]:
    #for w in jieba.cut(ent.select('.title')[0].text.strip()):
    if dic.get(w) is None:
        dic[w] = 1
    else:
        dic[w] = dic[w] + 1

sorted_x = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)
print "sorted result: "
for w in sorted_x:
    #print w[0], w[1], 
    print w[0], w[1], 

seg_list4 = jieba.cut_for_search(res.text)  # 搜索引擎模式
print "\n"
print("4. 搜索引擎模式:")
# print(", ".join(seg_list4))
a = ", ".join(seg_list4)
dic = {}
#print a.split(',')
for w in  [c.strip() for c in a.split(',')]:
    #for w in jieba.cut(ent.select('.title')[0].text.strip()):
    if dic.get(w) is None:
        dic[w] = 1
    else:
        dic[w] = dic[w] + 1

sorted_x = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)
print "\n"
print "sorted result: "
for w in sorted_x:
    #print w[0], w[1], 
    print w[0], w[1], 

#TF-IDF
tags = jieba.analyse.extract_tags(res.text, 200)
print "\n"
print "Output TF/IDF : "
print ",".join(tags)
#print type(tags)
#print type(seg_list4)

dic = {}
#print a.split(',')
# for w in  [c.strip() for c in a.split(',')]:
#     #for w in jieba.cut(ent.select('.title')[0].text.strip()):
#     if dic.get(w) is None:
#         dic[w] = 1
#     else:
#         dic[w] = dic[w] + 1

# sorted_x = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)
# print "sorted result: "
# for w in sorted_x:
#     #print w[0], w[1], 
#     print w[0], w[1]
# Out:
# Building prefix dict from E:\Project\patent\iiiedu\dict.txt.big ...
# DEBUG:jieba:Building prefix dict from E:\Project\patent\iiiedu\dict.txt.big ...
# Loading model from cache c:\users\bigdata\appdata\local\temp\jieba.u33b145b004b54eaa2d5f07e7b853ef69.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdata\appdata\local\temp\jieba.u33b145b004b54eaa2d5f07e7b853ef69.cache
# Loading model cost 0.603 seconds.
# DEBUG:jieba:Loading model cost 0.603 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 一種耐壓性、封密性及噪音性優異的渦形壓縮機，其固定渦形體1及活動渦形體8之渦形壁1b,8b之始端部1e,8c厚度係形成較渦形壁1b,8b之其他部位為厚。始端部1e,8c之內壁面呈如直線L1,L2所示之平面形狀，而藉由活動渦形體8之公轉兩平面L1,L2會相接或相離。支住該渦形壁1b,8b之頂端面嵌裝有封密構造15,16。封密構造15,16之始端部15a,16a係形成為寬闊的，以配合渦形壁1b,8b之始端部1e,8c之形狀(參照第2圖)。
#
#
#
# To offer a scroll type compressor having excellent properties against pressure, sealing and noise.
#
# ...

# %%
 1. Full Mode: 
sorted result: 
 586 之 212 渦 130 端 72 形體 68 始 67 形 60 部 60 排出 52 壁 51 密 51 封 50 為 47 構件 36 出口 36 活動 35 壓縮 33 固定 26 係 24 在 23 16 21 第 21 8 20 基板 19 8b 19 較 19 公轉 18 1d 18 可 18 室 18 1b 17 形成 17 其他 17 圖 17 和 17 厚度 17 以 16 1 16 形狀 16 使 15 將 15 部位 15 的 14 位置 14 及 14 於 14 而 13 所 13 8c 13 面積 13 the 13 L2 12 直線 12 圓弧 12 16a 12 提高 12 L1 11 1e 11 擴大 11 曲線 11 上 10 漸開 10 壓縮機 10 15 10 兩 10 時 10 側 10 間 9 壁面 9 氣體 9 如 9 孔徑 9 會 9 構造 9 則 9 滑 9 其 8 成 8 3 8 耐壓 8 本 8 耐壓性 8 孔 8 增大 8 斷面 8 創作 8 of 8 所示 8 該 7 越 7 出於 7 或 7 大 7 連結 7 限制 7 轉位 7 一種 6 端面 6 之間 6 高壓 6 11A 6 由於 6 性 6 2 6 履 6 內 6 採用 6 面對 6 著 6 11B 6 增加 6 頂端 6 5 6 支持 6 15a 6 且 5 10a 5 8a 5 一體 5 號 5 9a 5 周緣 5 流出 5 突 5 昭 5 作用 5 阻力 5 做成 5 E2 5 之一 5 1a 5 轉而 5 藉以 5 接 5 之內 5 are 5 圓形 5 因而 5 伸開 5 S 5 開 5 公報 5 之面 5 表示 5 4 5 上述 5 R12 5 因 5 地 5 portions 5 了 5 亦 5 相
 1 內側 1 之中 1 需要 1 而言 1 關於 1 1c 1 先端 1 大致 1 近於 1 compressor 1 剖 1 than 1 wide 1 14 1 諸如 1 亦需 1 進入 1 能 1 參照 1 寬 1 圓 1 先前 1 壓氣 1 內部 1 支 1 不限 1 膨脹 1 受損 1 導入 1 脈動 1 connected 1 起運 1 face 1 佳 1 卻 1 曾 1 背面 1 必須 1 閉塞 1 須 1 supported 1 入口 1 結束 1 反作用 1 體面 1 thicker 1 或以 1 裝置 1 壓 1 如下 1 兼用 1 基礎 1 運轉 1 只要 1 體會 1 鼓出 1 排氣 1 P1 1 中高 1 可隨 1 對位 1 砝碼 1 movalbe 1 地支 1 反力 1 P2 1 平面形 1 成因 1 排氣閥 1 可以 1 吸引力 1 穿過 1 faces 1 point 1 寬闊 1 氣閥 1 60 1 餘 1 變大 1 corresponding 1 抑制 1 於此 1 動 1 宛如 1 設在 1 可使 1 TYPE 1 整體 1 engaged 1 後 1 向 1 against 1 in 1 受到限制 1 128995 1 終端 1 並非 1 預定 1 面向 1 活 1 例子 1 只能 1 合成樹脂 1 要能 1 畫 1 面呈 1 達成 1 平衡 1 觸 1 高壓縮 1 一 1 以其 1 合理 1 避免 1 而有 1 都 1 獲得 1 伸出 1 越過 1 接觸 1 對於 1 SEALING 1 效率 1 惟 1 shaped 1 OF 1 樹脂 1 是 1 shapes 1 不讓 1 按 1 小會 1 下 1 使用 1 一般而言 1 for 1 面會 1 構成 1 面朝 1 阻 1 noise 1 在於 1 持有 1 pressure 1 properties 1 而延 1 出 1 小徑 1 需 1 型 1 防漏 1 最高 1 出行 1 滑動 1 旋轉軸 1 offer 1 量 1 CONSTRUCTION 1 僅限 1 任意 1 一起 1 planes 1 separated 1 對 1 To 1 自壓 1 特徵 1 合於 1 spreadly 1 選擇 1 面上 1 other 1 橢圓 1 包圍 1 而以 1 一致 1 因此 1 Sealing 1 一旦 1 方式 1 圓板狀 1 即 1 設於 1 SCROLL 1 

2. 精确模式:
sorted result: 
 431 之 157 ， 148 。 83 形體 68 渦 66 封密 40 為 38 端部 38 構件 36 出口 36 ‧ 36 活動 35 固定 26 之始 25 係 24 排 23 壓縮 23 而 21 在 21 16 21 形壁 20 8 20 第 20 基板 19 8b 19 公轉 18 1d 18 1b 17 形成 17 其他 17 可 17 室 17 和 17 厚度 17 於 17 1 16 較 16 渦形 16 之渦 15 排出 15 形狀 15 部位 15 的 14 以 14 始端部 14 位置 14 8c 13 及 13 the 13 L2 12 使 12 直線 12 所 12 圓弧 12 渦形壁 12 16a 12 L1 11 1e 11 面積 11 擴大 11 曲線 11 上 10 形壁始 10 壓縮機 10 15 10 提高 10 圖 10 氣體 9 孔徑 9 構造 9 會 9 壁面 8 漸開 8 有 8 - 8 端 8 3 8 本 8 耐壓性 8 增大 8 創作 8 因 8 of 8 所示 8 如 7 出於 7 兩渦 7 時 7 將 7 壁始 7 一種 6 其 6 之間 6 間 6 該 6 由於 6 或 6 2 6 大 6 限制 6 孔 6 採用 6 面對 6 11A 6 11B 6 
 1 橢圓形 1 separated 1 將成 1 中央 1 依據 1 接相 1 excellent 1 滑動 1 發生 1 圖說 1 內以 1 挾有球 1 完 1 較僅 1 有前 1 孔為 1 製成 1 rather 1 如於 1 殼 1 巡回 1 自始 1 movable 1 開昭 1 兩封 1 plane 1 a 1 流入 1 降低 1 lines 1 溝內 1 靠近 1 或僅 1 再 1 如上 1 Inner 1 同時 1 排完 1 並被 1 使始 1 端起 1 因渦 1 頗 1 前進 1 shown 1 性 1 乃 1 所有 1 完畢 1 到達 1 密 1 較厚 1 全部 1 fastening 1 面嵌 1 相對 1 變更 1 及渦 1 明 1 需要 1 關於 1 其始 1 1c 1 而成 1 較該 1 先端 1 大致 1 圓板狀 1 近於 1 compressor 1 than 1 wide 1 14 1 諸如 1 進入 1 畫成 1 側剖圖 1 寬 1 則如 1 先前 1 內部 1 接合 1 內壁 1 膨脹 1 受損 1 導入 1 脈動 1 connected 1 著排 1 除始 1 face 1 避免 1 可觸 1 卻 1 曾 1 背面 1 必須 1 一 1 supported 1 入口 1 結束 1 反作用 1 thicker 1 端部斷 1 接 1 裝置 1 將會 1 周面 1 如下 1 兼用 1 基礎 1 運轉 1 鼓出 1 會作 1 P1 1 密性 1 砝碼 1 movalbe 1 只要 1 反力 1 P2 1 其渦 1 排氣閥 1 都 1 可以 1 吸引力 1 穿過 1 則以 1 阻將 1 且始 1 faces 1 以排 1 支住 1 開放 1 point 1 愈 1 寬闊 1 60 1 則會 1 餘 1 溝 1 部越 1 變大 1 corresponding 1 抑制 1 於此 1 之側 1 向排 1 宛如 1 設在 1 至 1 TYPE 1 整體 1 engaged 1 against 1 in 1 使渦 1 受到限制 1 128995 1 終端 1 並非 1 預定 1 面向 1 邊被 1 活 1 例子 1 只能 1 並在 1 為大者 1 合成樹脂 1 若予 1 參照 1 達成 1 平衡 1 內外 1 固形渦 1 時所 1 使斷 1 挾進 1 側之 1 合理 1 側可 1 形型 1 合時 1 獲得 1 之滑履 1 伸出 1 限 1 越過 1 接觸 1 SEALING 1 效率 1 惟 1 shaped 1 OF 1 是 1 shapes 1 不讓 1 愈佳 1 按 1 下 1 高封 1 使用 1 兩滑履 1 一般而言 1 沿封密 1 for 1 構成 1 為圓 1 noise 1 在於 1 pressure 1 則封密 1 挾裝 1 小徑 1 需 1 防漏 1 最高 1 面以 1 旋轉軸 1 offer 1 嵌 1 CONSTRUCTION 1 地被 1 僅限 1 靠 1 越出 1 任意 1 較渦 1 上之量 1 一起 1 planes 1 端部間 1 邊 1 對 1 To 1 自貫 1 ； 1 特徵 1 合於 1 spreadly 1 選擇 1 面上 1 other 1 以壓 1 包圍 1 之周 1 一致 1 因此 1 Sealing 1 正 1 一旦 1 方式 1 沿排 1 即 1 設於 1 SCROLL 1 

3. 默认精确模式:
sorted result: 
 2 高 2 by 2 地使 2 之比 2 斷 2 性能 2 做 2 通過 2 軸襯 2 即將 2 隨之 2 又 2 互相 2 側之始 2 聚束 2 減低 2 周壁 2 外觀 1 如將 1 相離 1 合 1 壁上 1 自第 1 ： 1 著後殼 1 被 1 閉塞 1 使排 1 to 1 茲 1 嵌裝 1 令排 1 呈 1 直徑 1 孔而突 1 詳述 1 Co 1 除 1 之故 1 圖之沿 1 周 1 having 1 接近 1 straight 1 revolution 1 室內 1 適當 1 室之渦 1 帶來 1 途徑 1 ; 1 不 1 將排 1 用於 1 缺口 1 環狀 1 插 1 恰當 1 及球 1 COMPRESSOR 1 提供 1 無法 1 時之排 1 ~ 1 消除 1 加以 1 動渦 1 或實 1 地為 1 two 1 properties 1 須在 1 6 1 內側 1 將封密 1 type 1 橢圓形 1 separated 1 將成 1 中央 1 依據 1 接相 1 excellent 1 滑動 1 發生 1 圖說 1 內以 1 挾有球 1 完 1 較僅 1 有前 1 孔為 1 製成 1 rather 1 如於 1 殼 1 巡回 1 自始 1 movable 1 開昭 1 兩封 1 plane 1 a 1 流入 1 降低 1 lines 1 溝內 1 靠近 1 或僅 1 再 1 如上 1 Inner 1 同時 1 排完 1 並被 1 使始 1 端起 1 因渦 1 頗 1 前進 1 shown 1 性 1 乃 1 所有 1 完畢 1 到達 1 密 1 較厚 1 全部 1 fastening 1 面嵌 1 相對 1 變更 1 及渦 1 明 1 需要 1 關於 1 其始 1 1c 1 而成 1 較該 1 先端 1 大致 1 圓板狀 1 近於 1 compressor 1 than 1 wide 1 14 1 諸如 1 進入 1 畫成 1 側剖圖 1 寬 1 則如 1 先前 1 內部 1 接合 1 內壁 1 膨脹 1 受損 1 導入 1 脈動 1 connected 1 著排 1 除始 1 face 1 避免 1 可觸 1 卻 1 曾 1 背面 1 必須 1 一 1 supported 1 入口 1 結束 1 反作用 1 thicker 1 端部斷 1 接 1 裝置 1 將會 1 周面 1 如下 1 兼用 1 基礎 1 運轉 1 鼓出 1 會作 1 P1 1 密性 1 砝碼 1 movalbe 1 只要 1 反力 1 P2 1 其渦 1 排氣閥 1 都 1 可以 1 吸引力 1 穿過 1 則以 1 阻將 1 且始 1 faces 1 以排 1 支住 1 開放 1 point 1 愈 1 寬闊 1 60 1 則會 1 餘 1 溝 1 部越 1 變大 1 corresponding 1 抑制 1 於此 1 之側 1 向排 1 宛如 1 設在 1 至 1 TYPE 1 整體 1 engaged 1 against 1 in 1 使渦 1 受到限制 1 128995 1 終端 1 並非 1 預定 1 面向 1 邊被 1 活 1 例子 1 只能 1 並在 1 為大者 1 合成樹脂 1 若予 1 參照 1 達成 1 平衡 1 內外 1 固形渦 1 時所 1 使斷 1 挾進 1 側之 1 合理 1 側可 1 形型 1 合時 1 獲得 1 之滑履 1 伸出 1 限 1 越過 1 接觸 1 SEALING 1 效率 1 惟 1 shaped 1 OF 1 是 1 shapes 1 不讓 1 愈佳 1 按 1 下 1 高封 1 使用 1 兩滑履 1 一般而言 1 沿封密 1 for 1 構成 1 為圓 1 noise 1 在於 1 pressure 1 則封密 1 挾裝 1 小徑 1 需 1 防漏 1 最高 1 面以 1 旋轉軸 1 offer 1 嵌 1 CONSTRUCTION 1 地被 1 僅限 1 靠 1 越出 1 任意 1 較渦 1 上之量 1 一起 1 planes 1 端部間 1 邊 1 對 1 To 1 自貫 1 ； 1 特徵 1 合於 1 spreadly 1 選擇 1 面上 1 other 1 以壓 1 包圍 1 之周 1 一致 1 因此 1 Sealing 1 正 1 一旦 1 方式 1 沿排 1 即 1 設於 1 SCROLL 1 

4. 搜索引擎模式:


sorted result: 
 431 之 157 ， 148 。 83 形體 68 渦 66 封密 40 為 38 端部 38 構件 36 出口 36 ‧ 36 活動 35 壓縮 33 固定 26 之始 25 係 24 排 23 而 21 16 21 在 21 形壁 20 8 20 第 20 基板 19 8b 19 公轉 18 1d 18 1b 17 形成 17 其他 17 可 17 室 17 和 17 厚度 17 於 17 1 16 較 16 渦形 16 之渦 15 排出 15 形狀 15 部位 15 的 14 以 14 始端部 14 位置 14 8c 13 面積 13 及 13 the 13 L2 12 使 12 直線 12 所 12 圓弧 12 渦形壁 12 16a 12 提高 12 L1 11 1e 11 擴大 11 曲線 11 上 10 漸開 10 形壁始 10 壓縮機 10 15 10 圖 10 氣體 9 孔徑 9 構造 9 會 9 壁面 8 有 8 - 8 端 8 3 8 耐壓 8 本 8 耐壓性 8 增大 8 創作 8 因 8 of 8 所示 8 如 7 出於 7 限制 7 兩渦 7 時 7 將 7 壁始 7 一種 6 其 6 之間 6 間 6 該 6 由於 6 或 6 2 6 大 6 孔 6 採用 6 面對 6 11A 6 11B 6 增加 6 頂端 6 亦 6 5 6 支持 6 15a 6 10a 5 8a 5 一體 5 號 5 9a 5 周緣 5 流出 5 連結 5 成 5 阻力 5 越 5 做成 5 E2 5 之一 5 1a 5 圖為 5 藉以 5 are 5 因而 5 伸開 5 S 5 . 5 公報 5 表示 5 4 5 始端 5 上述 5 R12 5 R11 5 portions 5 了 5 相接 5 冷媒 5 且 4 所以 4 滑履 4 容積 4 狀態 4 高壓 4 So 4 配合 4 突端 4 剖面圖 4 運動 4 scroll 4 中 4 作用 4 walls 4 volute 4 E1 4 相同 4 此種 4 and 4 偏心 4 實施 4 圓 4 偏心軸 4 覆蓋 4 內 4 具有 4 環 4 之外 4 面 4 R22 4 減少 4 厚 4 例 4 剖面 4 日本 4 強度 4 特開 4 昭 4 寬度 4 封密性 4 心軸 4 / 4 亦可 4 揭示 4 旋轉 4 starting 4 R21 4 外 3 對策 3 S1 3 優異 3 部 3 α 3 距離 3 自如 3 配置 3 角 3 線 3 相 3 能 3 破損 3 之內 3 例如 3 自轉 3 當 3 之要 3 則 3 冷凍 3 半徑 3 並且 3 影響 3 若 3 冷凍劑 3 16b 3 受到 3 S2 3 部份 3 來 3 等 3 自 3 至少 3 地 3 者 3 滑接 3 側之渦 2 藉由 2 與 2 之斷 2 間隔 2 自排 2 漸開線 2 sealing 2 前殼 2 乃是 2 嵌合 2 58187 2 領域 2 、 2 改大 2 重疊 2 A 2 大幅提高 2 則可 2 Q1 2 具體實施 2 然而 2 部之斷 2 尖端 2 無論是 2 開線 2 效果 2 低 2 進行 2 造成 2 截面 2 從 2 7 2 狀 2 朝向 2 逐漸 2 再行 2 180 2 從而 2 13 2 12 2 之虞 2 介裝 2 Q2 2 The 2 行程 2 產生 2 不致 2 ( 2 貫 2 交點 2 面間 2 10 2 光滑 2 148088 2 裝有 2 儘量 2 切線 2 截面積 2 單純 2 Po 2 由 2 連通 2 改大排 2 側之封密 2 兩 2 近旁 2 大幅 2 之連 2 幅度 2 不能 2 共同 2 壓力 2 後續 2 結點 2 上之排 2 至渦 2 formed 2 設有 2 噪音 2 之多 2 一面 2 此 2 之比 2 將渦 2 具體 2 並使 2 ) 2 隨著 2 就 2 9 2 均 2 目的 2 平面 2 情況 2 即使 2 度 2 定於 2 components 2 長度 2 比值 2 延伸 2 59 2 57 2 數個 2 大小 2 著 2 高 2 by 2 地使 2 無論 2 斷 2 性能 2 做 2 通過 2 軸襯 2 即將 2 隨之 2 又 2 互相 2 側之始 2 聚束 2 減低 2 周壁 2 外觀 1 如將 1 相離 1 合 1 合成 1 壁上 1 自第 1 ： 1 著後殼 1 被 1 閉塞 1 使排 1 一般 1 to 1 茲 1 嵌裝 1 令排 1 排氣 1 呈 1 直徑 1 孔而突 1 Co 1 除 1 之故 1 圖之沿 1 周 1 詳述 1 接近 1 straight 1 revolution 1 室內 1 適當 1 室之渦 1 帶來 1 途徑 1 ; 1 不 1 將排 1 用於 1 缺口 1 環狀 1 插 1 恰當 1 及球 1 COMPRESSOR 1 提供 1 無法 1 時之排 1 ~ 1 消除 1 加以 1 動渦 1 或實 1 地為 1 two 1 properties 1 須在 1 6 1 內側 1 將封密 1 type 1 橢圓形 1 separated 1 將成 1 中央 1 依據 1 接相 1 excellent 1 滑動 1 發生 1 圖說 1 內以 1 挾有球 1 內外 1 完 1 較僅 1 有前 1 孔為 1 製成 1 rather 1 如於 1 殼 1 巡回 1 所有 1 movable 1 開昭 1 兩封 1 plane 1 a 1 流入 1 降低 1 lines 1 溝內 1 靠近 1 或僅 1 再 1 如上 1 Inner 1 同時 1 兩滑履 1 排完 1 並被 1 轉軸 1 引力 1 使始 1 端起 1 吸引 1 因渦 1 頗 1 前進 1 shown 1 性 1 乃 1 完畢 1 到達 1 密 1 較厚 1 全部 1 fastening 1 面嵌 1 相對 1 變更 1 自始 1 及渦 1 明 1 需要 1 而言 1 關於 1 其始 1 1c 1 而成 1 較該 1 先端 1 大致 1 圓板狀 1 近於 1 compressor 1 than 1 wide 1 14 1 諸如 1 進入 1 畫成 1 側剖圖 1 寬 1 則如 1 先前 1 內部 1 接合 1 板狀 1 內壁 1 膨脹 1 受損 1 密性 1 導入 1 脈動 1 connected 1 著排 1 除始 1 face 1 避免 1 可觸 1 卻 1 曾 1 背面 1 必須 1 一 1 supported 1 入口 1 結束 1 反作用 1 thicker 1 端部斷 1 接 1 裝置 1 將會 1 周面 1 如下 1 兼用 1 基礎 1 運轉 1 鼓出 1 會作 1 P1 1 圓形 1 砝碼 1 movalbe 1 只要 1 反力 1 P2 1 其渦 1 排氣閥 1 都 1 可以 1 吸引力 1 穿過 1 阻將 1 且始 1 faces 1 以排 1 支住 1 開放 1 point 1 愈 1 寬闊 1 氣閥 1 60 1 則會 1 餘 1 溝 1 部越 1 變大 1 corresponding 1 抑制 1 於此 1 之側 1 向排 1 宛如 1 設在 1 至 1 TYPE 1 整體 1 engaged 1 against 1 in 1 使渦 1 受到限制 1 128995 1 終端 1 並非 1 預定 1 面向 1 邊被 1 活 1 例子 1 只能 1 並在 1 為大者 1 合成樹脂 1 若予 1 參照 1 達成 1 平衡 1 固形渦 1 時所 1 使斷 1 挾進 1 側之 1 合理 1 側可 1 形型 1 合時 1 獲得 1 之滑履 1 伸出 1 限 1 越過 1 接觸 1 SEALING 1 效率 1 惟 1 shaped 1 OF 1 是 1 shapes 1 不讓 1 愈佳 1 樹脂 1 按 1 下 1 高封 1 使用 1 一般而言 1 沿封密 1 for 1 構成 1 為圓 1 noise 1 在於 1 pressure 1 則封密 1 挾裝 1 小徑 1 需 1 防漏 1 最高 1 面以 1 旋轉軸 1 offer 1 嵌 1 CONSTRUCTION 1 地被 1 僅限 1 靠 1 越出 1 任意 1 較渦 1 上之量 1 一起 1 planes 1 端部間 1 邊 1 對 1 則以 1 To 1 自貫 1 ； 1 特徵 1 合於 1 spreadly 1 選擇 1 面上 1 other 1 橢圓 1 以壓 1 包圍 1 之周 1 一致 1 因此 1 Sealing 1 正 1 一旦 1 方式 1 沿排 1 having 1 即 1 設於 1 SCROLL 1 

Output TF/IDF : 
形體,封密,端部,活動,構件,固定,壓縮,形壁,基板,8b,之始,公轉,1d,1b,其他,厚度,出口,渦形,之渦,排出,部位,始端部,8c,L2,直線,渦形壁,16a,L1,1e,面積,擴大,圓弧,形壁始,壓縮機,耐壓性,氣體,構造,形狀,漸開,增大,創作,所示,孔徑,壁面,兩渦,壁始,曲線,位置,形成,由於,限制,採用,面對,11A,11B,增加,支持,15a,10a,8a,一體,9a,流出,阻力,E2,1a,圖為,伸開,公報,表示,始端,上述,R12,R11,portions,相接,冷媒,藉以,周緣,所以,滑履,容積,So,配合,突端,剖面圖,強度,walls,高壓,volute,E1,偏心軸,R22,日本,特開,寬度,封密性,亦可,scroll,starting,R21,提高,頂端,出於,連結,做成,對策,S1,優異,配置,破損,自轉,之要,16b,冷凍劑,S2,部份,至少,滑接,揭示,因而,覆蓋,自如,漸開線,半徑,側之渦,之斷,自排,sealing,前殼,乃是,58187,大幅提高,則可,Q1,具體實施,然而,部之斷,無論是,數個,造成,逐漸,再行,180,間隔,之虞,介裝,Q2,實施,嵌合,受到,行程,周壁,交點,面間,148088,裝有,儘量,截面積,單純,Po,連通,改大排,側之封密,之連,不能,共同,壓力,上之排,至渦,formed,設有,噪音,一面,將渦,並使,領域,目的,即使,components,比值,延伸,地使,性能,軸襯,即將,側之始,聚束,產生,之外,之一,狀態,結點,旋轉,減少,切線,近旁,運動,之內,朝向
